# %%
import tensorflow as tf

# %%
tensor_zero_d = tf.constant(4)
print(tensor_zero_d)
# Out:
# tf.Tensor(4, shape=(), dtype=int32)

# %%
tensor_one_d = tf.constant([2,1])
print(tensor_one_d)
# Out:
# tf.Tensor([2 1], shape=(2,), dtype=int32)
